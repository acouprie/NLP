# %%
# !pip install --user nltk
# Out:
# touch: cannot touch '/usr/local/cuda/compat/.440.36.co2-slurm-ng02.checked': Read-only file system
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...

# %%
import nltk
import json
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize

# %%
OUTPUT_FILE = '/users/tweetcontextualization/acouprie/ukenvironmental/outputs/sentence_extraction-bis.txt'

json_file = open('./resources/all_sentences.json',"r")
output = open(OUTPUT_FILE,"a")
documents = json.loads(json_file.read())
sentences.close()
tokenize = {}
for key, value in documents.items():
    tokens = sent_tokenize(value)
    tokenize[key] = tokens
    for token in tokens:
        if "terror" in token or "Terror" in token:
            output.write(token + "\n")
output.close()

# %%
sentences = open('./resources/terror_tokens.txt',"r")
# Process whole documents
text = (sentences.read())
sentences.close()
tokens = [t for t in text.split()]

clean_tokens = tokens[:]

sr = stopwords.words('english')

for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)
freq.plot(20,cumulative=False)

# %%
sentences = open('./resources/AFC/sentences_without_terror_1.txt',"r")
# Process whole documents
text = (sentences.read())
sentences.close()
tokens = [t for t in text.split()]
clean_tokens = tokens[:]
sr = stopwords.words('english')
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)
freq.plot(20,cumulative=False)

# %%
from nltk.corpus import wordnet
synonyms = []
for syn in wordnet.synsets('terrorism'):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())

print(synonyms)
# Out:
# ['terrorism', 'act_of_terrorism', 'terrorist_act']
